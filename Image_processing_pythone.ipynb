# %% [markdown]
# # Load image use scikit-image, matplotlib
# convert to gray
# convert to rgb
# .shape to see 3 ndarray on rgb image
# .shape to see 2 ndarray on gray image

# %%
import matplotlib.pyplot as plt
from skimage import data, color
import numpy as np
bw_pic = plt.imread('bw.jpg')
plt.imshow(bw_pic)

# %%
def show_image(image, title = 'Image', cmap_type = 'gray'):
  plt.imshow(image, cmap= cmap_type)
  plt.title(title)
  plt.axis('off')    # no show for the axis scale on show image
  plt.show()

# %%
# Import the modules from skimage
# from skimage import data, color

# Load the rocket image
rocket = data.rocket()

# Convert the image to grayscale
gray_scaled_rocket = color.rgb2gray(rocket)

# Show the original image
show_image(rocket, 'Original RGB image')

# Show the grayscale image
show_image(gray_scaled_rocket, 'Grayscale image')

# %% [markdown]
# # Test grayscale image to RGB

# %%
gray_scaled_rocket_to_rgb_test = color.gray2rgb(gray_scaled_rocket)
# show_image(gray_scaled_rocket_to_rgb_test, 'gray2rgb_test', cmap_type= 'color
plt.imshow(gray_scaled_rocket_to_rgb_test)

# %% [markdown]
# Test fail can not get back color
# once convert 3 dimension to 2 dimension gray image. it's gone.

# %% [markdown]
# # Flipup image
# and fliplr ==> flip horizontal

# %%
seville = plt.imread('sevilleup(2).jpg')
# flipped_down = np.flipud(seville)
plt.imshow(seville)
plt.show()

# this for not use %matplotlib inline and show the x-axis and y-axis

# %%
# Flip the image vertically
seville_vertical_flip = np.flipud(seville)

# Flip the image horizontally
seville_horizontal_flip = np.fliplr(seville_vertical_flip)

# Show the resulting image
show_image(seville_horizontal_flip, 'Seville')

# %%
show_image(seville_vertical_flip, 'Seville flip up before filplr')

# %% [markdown]
# # HISTOGRAM
# .ravel() use for flatten 3 color to one flat dimension
# red green blue dimension explore
# red = image[:, :, 0]
# green = image[:, :, 1]
# blue = image[:, :, 2]
#
#
#
# in each pixel value 0-255 (256 number)
# in each 3 color dimension.

# %%
women = plt.imread('4.1.01.tiff')

show_image(women, 'women')

# %%
women[:, :, 0]
# Out:
# array([[ 52,  47,  50, ..., 137, 126, 126],
#        [ 55,  50,  54, ..., 129, 129, 121],
#        [ 46,  49,  52, ..., 126, 123, 118],
#        ...,
#        [  4,   3,   3, ...,  60,  84,  98],
#        [ 11,  12,  12, ...,  60,  86, 100],
#        [ 20,  19,  20, ...,  55,  70,  93]], dtype=uint8)

# %%
plt.imshow(women[:, :, 0])

# %%
plt.imshow(women[:, :, 1])

# %%
plt.imshow(women[:, :, 2])

# %%
# Obtain the red channel
red_channel = women[:, :, 0]

# Plot the red histogram with bains in a range of 256
plt.hist(red_channel.ravel(), bins=256)

# Set title and show
plt.title('Red Histogram')
plt.show()

# %%
# Obtain the red channel
green_channel = women[:, :, 1]

# Plot the red histogram with bains in a range of 256
plt.hist(green_channel.ravel(), bins=256)

# Set title and show
plt.title('Green Histogram')
plt.show()

# %%
# Obtain the red channel
blue_channel = women[:, :, 2]

# Plot the red histogram with bains in a range of 256
plt.hist(blue_channel.ravel(), bins=256)

# Set title and show
plt.title('Blue Histogram')
plt.show()

# %%
plt.subplot(3,1,1)     # index number is the order number of pic
plt.hist(blue_channel.ravel(), bins=256)
plt.title('blue_channel')
plt.show()
plt.subplot(3,1,2)
plt.hist(red_channel.ravel(), bins=256)
plt.title('red_channel')
plt.show()
plt.subplot(3,1,3)
plt.hist(green_channel.ravel(), bins=256)
plt.title('green_channel')
plt.show()

# %% [markdown]
# # Threshold
# define good Threshold by use optimal threshold
# inverted threshold
# 255 >
# 0 <
#
# from skimage.filter import try_all_threshold
#
# will return 7 type threshold compare with original
#
#
# if global background is uniform is proper for:
#
#
# from skimage import threshold_otsu
# thresh =  threshold_otsu(image)
# binary_global = image > thresh

# %% [markdown]
# ถ้า background not uniform ต้องใช้ block size (เหมือนเป็นการเปรียบเที่ยบ แค่ block ใกล้ๆ) คือ การใช้ threshole_local
#
# from skimage import threshold_local
# -- the block size to 35
# block_size = 35
# มันคือการจำกัดว่า block size รอบๆ ตัวของแต่ละ pixel หรือเรียกอีกอย่างว่า  local neighborhoods

# %% [markdown]
# -- #Obtain the optimal thresholding
#
# local_thresh = threshold_local(text_image, block_size, offset=10)
#
#
# -- #Apply local thresholding and obtain the binary image
#
# binary_local = text_image > local_thresh

# %% [markdown]
# # Apply global threshold

# %%
from skimage.filters import threshold_otsu
from skimage.color import rgb2gray
from skimage import  data

img = data.astronaut()
plt.imshow(img)
plt.show()
img_gray = rgb2gray(img)
print(img_gray)
plt.imshow(img_gray, cmap= 'gray')
plt.show()

thresh = threshold_otsu(img_gray)
print(thresh)

binary = img_gray > thresh   #ที่มากว่ากว่า thresh ก็จะเป็น True =1 จะขาว เลข ส่วนที่น้อยกว่าจะ False =0 เป็นสีดำ 
print(binary)

show_image(binary, 'Binary image')
# Out:
# [[5.83434902e-01 4.14859216e-01 2.44058431e-01 ... 4.75007843e-01
#   4.58213333e-01 4.69121961e-01]
#  [6.75588235e-01 5.56006667e-01 4.49052941e-01 ... 4.68548627e-01
#   4.56501176e-01 4.55958431e-01]
#  [7.66334902e-01 7.00524314e-01 6.49276078e-01 ... 4.76406667e-01
#   4.62104314e-01 4.53978431e-01]
#  ...
#  [6.81696471e-01 6.81979216e-01 6.71889020e-01 ... 0.00000000e+00
#   2.82745098e-04 0.00000000e+00]
#  [6.74694510e-01 6.68532941e-01 6.64030196e-01 ... 2.82745098e-04
#   3.92156863e-03 0.00000000e+00]
#  [6.70482353e-01 6.63189804e-01 6.52838824e-01 ... 0.00000000e+00
#   3.92156863e-03 0.00000000e+00]]
# 0.388671875
# [[ True  True False ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  ...
#  [ True  True  True ... False False False]
#  [ True  True  True ... False False False]
#  [ True  True  True ... False False False]]

# %% [markdown]
# # When the background isn't obvious
# threshold_local a.k.a local thresholding produce better result

# %%
from skimage.filters import threshold_otsu
from skimage.color import rgb2gray
import matplotlib.pyplot as plt

page_image = plt.imread('text_page_original.png')
page_image = rgb2gray(page_image)
# plt.imshow(page_image, cmap= 'gray')

global_thresh = threshold_otsu(page_image)
print(global_thresh)
binary_global = page_image > global_thresh

show_image(binary_global, 'Global thresholding')
# Out:
# 0.52539057

# %%
# Import the local threshold function
from skimage.filters import threshold_local

# Set the block size to 35
block_size = 35


page_image = plt.imread('text_page_original.png')
page_image = rgb2gray(page_image)

# Obtain the optimal local thresholding
local_thresh = threshold_local(page_image, block_size = block_size, offset= 0.1)
print(local_thresh)
# Obtain the binary image by applying local thresholding
binary_local = page_image > local_thresh

# Show the binary image
show_image(binary_local, 'Local thresholding')
# Out:
# [[0.45486926 0.4554911  0.45669355 ... 0.58208003 0.58246478 0.58265974]
#  [0.45474376 0.45535552 0.45653859 ... 0.5817637  0.58213924 0.58232949]
#  [0.45450769 0.45509942 0.45624392 ... 0.58113814 0.58149435 0.58167471]
#  ...
#  [0.61542549 0.61553791 0.61575485 ... 0.58976528 0.58983304 0.58987087]
#  [0.61511189 0.61523175 0.61546289 ... 0.5900927  0.59013873 0.59016523]
#  [0.61494524 0.61506898 0.61530751 ... 0.59026111 0.59029578 0.59031638]]

# %% [markdown]
# # Trying other methods
#
# try_all_threshold() to try multiple global algorithms.

# %%
# Import the try all function
from skimage.filters import try_all_threshold

# Import the rgb to gray convertor function 
from skimage.color import rgb2gray

fruits_image = plt.imread('fruits-2.jpg')
# page_image = rgb2gray(page_image)

# Turn the fruits_image to grayscale
grayscale = rgb2gray(fruits_image)

# Use the try all method on the resulting grayscale image
fig, ax = try_all_threshold(grayscale, verbose=False)

# Show the resulting plots
plt.show()

# %% [markdown]
# Nice! As you see, this image works good with some global thresholding methods (like the "Yen" and "Mean") and not so well in others, (like the "Minimum").

# %%
from skimage.filters import try_all_threshold
from skimage.color import rgb2gray
import matplotlib.pyplot as plt

# Turn the image grayscale
tools_image = plt.imread('shapes52.jpg')
gray_tools_image = rgb2gray(tools_image)

# Obtain the optimal thresh
thresh = threshold_otsu(gray_tools_image)

# Obtain the binary image by applying thresholding
binary_image = gray_tools_image > thresh

# Show the resulting binary image
show_image(binary_image, 'Binarized image')
